# %% [markdown]
# ## Import necessary library

# %%
import os

import boto3
import sagemaker
from sagemaker.sklearn import SKLearn
from sagemaker.local import LocalSession

import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: C:\ProgramData\sagemaker\sagemaker\config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: C:\Users\tochi\AppData\Local\sagemaker\sagemaker\config.yaml

# %% [markdown]
# ## Specify sagemaker session and role

# %%
sagemaker_local_session = LocalSession()
sagemaker_local_session.config = {'local': {'local_code': True}}
account = boto3.client('sts').get_caller_identity().get('Account')
role = f"arn:aws:iam::{account}:role/service-role/AmazonSageMakerServiceCatalogProductsUseRole"
# Out:
# Windows Support for Local Mode is Experimental

# %% [markdown]
# ## Train the model locally

# %%
training_input_path = "s3://modeldata1234567/train/train.csv"
local_output_path = 'file:///Users/tochi/OneDrive/Documents/Train_with_Sagemaker_locally/trained_model'
remote_output_path = 's3://sagemaker-us-east-2-930627915954/local_model/'
sk_estimator = SKLearn(
    session=sagemaker_local_session,
    entry_point="train.py", 
    role=role,
    job_name = "local_training",
    instance_count=1,
    instance_type='local',
    py_version="py3",
    framework_version="1.2-1",
    hyperparameters={"n_estimators":4},
    output_path = local_output_path
)
sk_estimator.fit({'train': training_input_path})
# Out:
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# WARNING:sagemaker.local.local_session:Windows Support for Local Mode is Experimental
# INFO:sagemaker:Creating training-job with name: sagemaker-scikit-learn-2024-09-05-21-26-49-918
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.local.image:'Docker Compose' found using Docker CLI.
# INFO:sagemaker.local.local_session:Starting training job
# INFO:sagemaker.local.image:Using the long-lived AWS credentials found in session
# INFO:sagemaker.local.image:docker compose file:
# networks:
#   sagemaker-local:
#     name: sagemaker-local
# services:
#   algo-1-5byfx:
#     command: train
#     container_name: 7cygyljrac-algo-1-5byfx
#     environment:
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     image: 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3
#     networks:
#       sagemaker-local:
#         aliases:
#         - algo-1-5byfx
#     stdin_open: true
#     tty: true
#     volumes:
#     - C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\algo-1-5byfx\output/data:/opt/ml/output/data
#     - C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\algo-1-5byfx\input:/opt/ml/input
#     - C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\algo-1-5byfx\output:/opt/ml/output
#     - C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\model:/opt/ml/model
#     - C:\Users\tochi\AppData\Local\Temp\tmpkqbb1ip6:/opt/ml/input/data/train
# version: '2.3'
#
# INFO:sagemaker.local.image:docker command: docker compose -f C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\docker-compose.yaml up --build --abort-on-container-exit
# time="2024-09-05T16:26:55-05:00" level=warning msg="a network with name sagemaker-local exists but was not created for project \"tmpo4qy47np\".\nSet `external: true` to use an existing network"
#  Container 7cygyljrac-algo-1-5byfx  Creating
#  Container 7cygyljrac-algo-1-5byfx  Created
# Attaching to 7cygyljrac-algo-1-5byfx
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,263 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,266 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,268 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,303 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,308 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,601 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,604 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,630 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,638 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,640 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,664 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,671 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,673 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,695 sagemaker-training-toolkit INFO     instance_groups entry not present in resource_config
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,701 sagemaker-training-toolkit INFO     Invoking user script
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | Training Env:
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | {
# 7cygyljrac-algo-1-5byfx  |     "additional_framework_parameters": {},
# 7cygyljrac-algo-1-5byfx  |     "channel_input_dirs": {
# 7cygyljrac-algo-1-5byfx  |         "train": "/opt/ml/input/data/train"
# 7cygyljrac-algo-1-5byfx  |     },
# 7cygyljrac-algo-1-5byfx  |     "current_host": "algo-1-5byfx",
# 7cygyljrac-algo-1-5byfx  |     "current_instance_group": "homogeneousCluster",
# 7cygyljrac-algo-1-5byfx  |     "current_instance_group_hosts": [],
# 7cygyljrac-algo-1-5byfx  |     "current_instance_type": "local",
# 7cygyljrac-algo-1-5byfx  |     "distribution_hosts": [
# 7cygyljrac-algo-1-5byfx  |         "algo-1-5byfx"
# 7cygyljrac-algo-1-5byfx  |     ],
# 7cygyljrac-algo-1-5byfx  |     "distribution_instance_groups": [],
# 7cygyljrac-algo-1-5byfx  |     "framework_module": "sagemaker_sklearn_container.training:main",
# 7cygyljrac-algo-1-5byfx  |     "hosts": [
# 7cygyljrac-algo-1-5byfx  |         "algo-1-5byfx"
# 7cygyljrac-algo-1-5byfx  |     ],
# 7cygyljrac-algo-1-5byfx  |     "hyperparameters": {
# 7cygyljrac-algo-1-5byfx  |         "n_estimators": 4
# 7cygyljrac-algo-1-5byfx  |     },
# 7cygyljrac-algo-1-5byfx  |     "input_config_dir": "/opt/ml/input/config",
# 7cygyljrac-algo-1-5byfx  |     "input_data_config": {
# 7cygyljrac-algo-1-5byfx  |         "train": {
# 7cygyljrac-algo-1-5byfx  |             "TrainingInputMode": "File"
# 7cygyljrac-algo-1-5byfx  |         }
# 7cygyljrac-algo-1-5byfx  |     },
# 7cygyljrac-algo-1-5byfx  |     "input_dir": "/opt/ml/input",
# 7cygyljrac-algo-1-5byfx  |     "instance_groups": [],
# 7cygyljrac-algo-1-5byfx  |     "instance_groups_dict": {},
# 7cygyljrac-algo-1-5byfx  |     "is_hetero": false,
# 7cygyljrac-algo-1-5byfx  |     "is_master": true,
# 7cygyljrac-algo-1-5byfx  |     "is_modelparallel_enabled": null,
# 7cygyljrac-algo-1-5byfx  |     "is_smddpmprun_installed": false,
# 7cygyljrac-algo-1-5byfx  |     "is_smddprun_installed": false,
# 7cygyljrac-algo-1-5byfx  |     "job_name": "sagemaker-scikit-learn-2024-09-05-21-26-49-918",
# 7cygyljrac-algo-1-5byfx  |     "log_level": 20,
# 7cygyljrac-algo-1-5byfx  |     "master_hostname": "algo-1-5byfx",
# 7cygyljrac-algo-1-5byfx  |     "model_dir": "/opt/ml/model",
# 7cygyljrac-algo-1-5byfx  |     "module_dir": "s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-09-05-21-26-49-918/source/sourcedir.tar.gz",
# 7cygyljrac-algo-1-5byfx  |     "module_name": "train",
# 7cygyljrac-algo-1-5byfx  |     "network_interface_name": "eth0",
# 7cygyljrac-algo-1-5byfx  |     "num_cpus": 20,
# 7cygyljrac-algo-1-5byfx  |     "num_gpus": 0,
# 7cygyljrac-algo-1-5byfx  |     "num_neurons": 0,
# 7cygyljrac-algo-1-5byfx  |     "output_data_dir": "/opt/ml/output/data",
# 7cygyljrac-algo-1-5byfx  |     "output_dir": "/opt/ml/output",
# 7cygyljrac-algo-1-5byfx  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# 7cygyljrac-algo-1-5byfx  |     "resource_config": {
# 7cygyljrac-algo-1-5byfx  |         "current_host": "algo-1-5byfx",
# 7cygyljrac-algo-1-5byfx  |         "hosts": [
# 7cygyljrac-algo-1-5byfx  |             "algo-1-5byfx"
# 7cygyljrac-algo-1-5byfx  |         ]
# 7cygyljrac-algo-1-5byfx  |     },
# 7cygyljrac-algo-1-5byfx  |     "user_entry_point": "train.py"
# 7cygyljrac-algo-1-5byfx  | }
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | Environment variables:
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | SM_HOSTS=["algo-1-5byfx"]
# 7cygyljrac-algo-1-5byfx  | SM_NETWORK_INTERFACE_NAME=eth0
# 7cygyljrac-algo-1-5byfx  | SM_HPS={"n_estimators":4}
# 7cygyljrac-algo-1-5byfx  | SM_USER_ENTRY_POINT=train.py
# 7cygyljrac-algo-1-5byfx  | SM_FRAMEWORK_PARAMS={}
# 7cygyljrac-algo-1-5byfx  | SM_RESOURCE_CONFIG={"current_host":"algo-1-5byfx","hosts":["algo-1-5byfx"]}
# 7cygyljrac-algo-1-5byfx  | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# 7cygyljrac-algo-1-5byfx  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# 7cygyljrac-algo-1-5byfx  | SM_CHANNELS=["train"]
# 7cygyljrac-algo-1-5byfx  | SM_CURRENT_HOST=algo-1-5byfx
# 7cygyljrac-algo-1-5byfx  | SM_CURRENT_INSTANCE_TYPE=local
# 7cygyljrac-algo-1-5byfx  | SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# 7cygyljrac-algo-1-5byfx  | SM_CURRENT_INSTANCE_GROUP_HOSTS=[]
# 7cygyljrac-algo-1-5byfx  | SM_INSTANCE_GROUPS=[]
# 7cygyljrac-algo-1-5byfx  | SM_INSTANCE_GROUPS_DICT={}
# 7cygyljrac-algo-1-5byfx  | SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# 7cygyljrac-algo-1-5byfx  | SM_IS_HETERO=false
# 7cygyljrac-algo-1-5byfx  | SM_MODULE_NAME=train
# 7cygyljrac-algo-1-5byfx  | SM_LOG_LEVEL=20
# 7cygyljrac-algo-1-5byfx  | SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# 7cygyljrac-algo-1-5byfx  | SM_INPUT_DIR=/opt/ml/input
# 7cygyljrac-algo-1-5byfx  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# 7cygyljrac-algo-1-5byfx  | SM_OUTPUT_DIR=/opt/ml/output
# 7cygyljrac-algo-1-5byfx  | SM_NUM_CPUS=20
# 7cygyljrac-algo-1-5byfx  | SM_NUM_GPUS=0
# 7cygyljrac-algo-1-5byfx  | SM_NUM_NEURONS=0
# 7cygyljrac-algo-1-5byfx  | SM_MODEL_DIR=/opt/ml/model
# 7cygyljrac-algo-1-5byfx  | SM_MODULE_DIR=s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-09-05-21-26-49-918/source/sourcedir.tar.gz
# 7cygyljrac-algo-1-5byfx  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-5byfx","current_instance_group":"homogeneousCluster","current_instance_group_hosts":[],"current_instance_type":"local","distribution_hosts":["algo-1-5byfx"],"distribution_instance_groups":[],"framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1-5byfx"],"hyperparameters":{"n_estimators":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":[],"instance_groups_dict":{},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":false,"job_name":"sagemaker-scikit-learn-2024-09-05-21-26-49-918","log_level":20,"master_hostname":"algo-1-5byfx","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-930627915954/sagemaker-scikit-learn-2024-09-05-21-26-49-918/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":20,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-5byfx","hosts":["algo-1-5byfx"]},"user_entry_point":"train.py"}
# 7cygyljrac-algo-1-5byfx  | SM_USER_ARGS=["--n_estimators","4"]
# 7cygyljrac-algo-1-5byfx  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# 7cygyljrac-algo-1-5byfx  | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# 7cygyljrac-algo-1-5byfx  | SM_HP_N_ESTIMATORS=4
# 7cygyljrac-algo-1-5byfx  | PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python38.zip:/miniconda3/lib/python3.8:/miniconda3/lib/python3.8/lib-dynload:/miniconda3/lib/python3.8/site-packages
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | Invoking script with the following command:
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | /miniconda3/bin/python train.py --n_estimators 4
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,702 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:56,702 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# 7cygyljrac-algo-1-5byfx  | Training data directory: /opt/ml/input/data/train
# 7cygyljrac-algo-1-5byfx  | Training data directory: 4
# 7cygyljrac-algo-1-5byfx  | Training data directory: /opt/ml/model
# 7cygyljrac-algo-1-5byfx  |        0  ...    3
# 7cygyljrac-algo-1-5byfx  | 0    5.1  ...  0.2
# 7cygyljrac-algo-1-5byfx  | 1    4.9  ...  0.2
# 7cygyljrac-algo-1-5byfx  | 2    4.7  ...  0.2
# 7cygyljrac-algo-1-5byfx  | 3    4.6  ...  0.2
# 7cygyljrac-algo-1-5byfx  | 4    5.0  ...  0.2
# 7cygyljrac-algo-1-5byfx  | ..   ...  ...  ...
# 7cygyljrac-algo-1-5byfx  | 115  6.4  ...  2.3
# 7cygyljrac-algo-1-5byfx  | 116  6.5  ...  1.8
# 7cygyljrac-algo-1-5byfx  | 117  7.7  ...  2.2
# 7cygyljrac-algo-1-5byfx  | 118  7.7  ...  2.3
# 7cygyljrac-algo-1-5byfx  | 119  6.0  ...  1.5
# 7cygyljrac-algo-1-5byfx  |
# 7cygyljrac-algo-1-5byfx  | [120 rows x 4 columns]
# 7cygyljrac-algo-1-5byfx  | 0      0
# 7cygyljrac-algo-1-5byfx  | 1      0
# 7cygyljrac-algo-1-5byfx  | 2      0
# 7cygyljrac-algo-1-5byfx  | 3      0
# 7cygyljrac-algo-1-5byfx  | 4      0
# 7cygyljrac-algo-1-5byfx  |       ..
# 7cygyljrac-algo-1-5byfx  | 115    2
# 7cygyljrac-algo-1-5byfx  | 116    2
# 7cygyljrac-algo-1-5byfx  | 117    2
# 7cygyljrac-algo-1-5byfx  | 118    2
# 7cygyljrac-algo-1-5byfx  | 119    2
# 7cygyljrac-algo-1-5byfx  | Name: 4, Length: 120, dtype: int64
# 7cygyljrac-algo-1-5byfx  | 2024-09-05 21:26:57,483 sagemaker-containers INFO     Reporting training SUCCESS
# INFO:root:creating C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\artifacts\output\data
# INFO:root:copying C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\algo-1-5byfx\output\success -> C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\artifacts\output
# INFO:root:copying C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\model\model.joblib -> C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\artifacts\model
# INFO:root:copying C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\compressed_artifacts\model.tar.gz -> C:\Users\tochi\OneDrive\Documents\Train_with_Sagemaker_locally\trained_model
# INFO:root:copying C:\Users\tochi\AppData\Local\Temp\tmpo4qy47np\compressed_artifacts\output.tar.gz -> C:\Users\tochi\OneDrive\Documents\Train_with_Sagemaker_locally\trained_model
# INFO:sagemaker.local.image:===== Job Complete =====
# 7cygyljrac-algo-1-5byfx exited with code 0
# Aborting on container exit...
#  Container 7cygyljrac-algo-1-5byfx  Stopping
#  Container 7cygyljrac-algo-1-5byfx  Stopped

# %% [markdown]
# ## Deploy Model Locally

# %%
predictor = sk_estimator.deploy(initial_instance_count=1, instance_type="local")
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-scikit-learn-2024-09-06-00-27-08-104
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating endpoint-config with name sagemaker-scikit-learn-2024-09-06-00-27-08-104
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker:Creating endpoint with name sagemaker-scikit-learn-2024-09-06-00-27-08-104
# INFO:sagemaker.telemetry.telemetry_logging:SageMaker Python SDK will collect telemetry to help us better understand our user's needs, diagnose issues, and deliver additional features.
# To opt out of telemetry, please disable via TelemetryOptOut parameter in SDK defaults config. For more information, refer to https://sagemaker.readthedocs.io/en/stable/overview.html#configuring-and-using-defaults-with-the-sagemaker-python-sdk.
# INFO:sagemaker.local.image:'Docker Compose' found using Docker CLI.
# INFO:sagemaker.local.image:serving
# INFO:sagemaker.local.image:creating hosting dir in C:\Users\tochi\AppData\Local\Temp\tmpxvl01t2p
# INFO:sagemaker.local.image:Using the long-lived AWS credentials found in session
# INFO:sagemaker.local.image:docker compose file:
# networks:
#   sagemaker-local:
#     name: sagemaker-local
# services:
#   algo-1-l8eyk:
#     command: serve
#     container_name: fae2hmw08w-algo-1-l8eyk
#     environment:
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     - '[Masked]'
#     image: 257758044811.dkr.ecr.us-east-2.amazonaws.com/sagemaker-scikit-learn:1.2-1-cpu-py3
#     networks:
#       sagemaker-local:
#         aliases:
#         - algo-1-l8eyk
#     ports:
#     - 8080:8080
#     stdin_open: true
#     tty: true
#     volumes:
#     - C:\Users\tochi\OneDrive\Documents\Train_with_Sagemaker_locally\trained_model:/opt/ml/model
# version: '2.3'
#
# INFO:sagemaker.local.image:docker command: docker compose -f C:\Users\tochi\AppData\Local\Temp\tmpxvl01t2p\docker-compose.yaml up --build --abort-on-container-exit
# INFO:sagemaker.local.entities:Checking if serving container is up, attempt: 5
# Attaching to fae2hmw08w-algo-1-l8eyk
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /ping
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /ping
# INFO:sagemaker.local.entities:Container still not up, got: -1
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:12,711 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:12,714 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:12,715 INFO - sagemaker-containers - nginx config:
# fae2hmw08w-algo-1-l8eyk  | worker_processes auto;
# fae2hmw08w-algo-1-l8eyk  | daemon off;
# fae2hmw08w-algo-1-l8eyk  | pid /tmp/nginx.pid;
# fae2hmw08w-algo-1-l8eyk  | error_log  /dev/stderr;
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  | worker_rlimit_nofile 4096;
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  | events {
# fae2hmw08w-algo-1-l8eyk  |   worker_connections 2048;
# fae2hmw08w-algo-1-l8eyk  | }
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  | http {
# fae2hmw08w-algo-1-l8eyk  |   include /etc/nginx/mime.types;
# fae2hmw08w-algo-1-l8eyk  |   default_type application/octet-stream;
# fae2hmw08w-algo-1-l8eyk  |   access_log /dev/stdout combined;
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |   upstream gunicorn {
# fae2hmw08w-algo-1-l8eyk  |     server unix:/tmp/gunicorn.sock;
# fae2hmw08w-algo-1-l8eyk  |   }
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |   server {
# fae2hmw08w-algo-1-l8eyk  |     listen 8080 deferred;
# fae2hmw08w-algo-1-l8eyk  |     client_max_body_size 0;
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |     keepalive_timeout 3;
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |     location ~ ^/(ping|invocations|execution-parameters) {
# fae2hmw08w-algo-1-l8eyk  |       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
# fae2hmw08w-algo-1-l8eyk  |       proxy_set_header Host $http_host;
# fae2hmw08w-algo-1-l8eyk  |       proxy_redirect off;
# fae2hmw08w-algo-1-l8eyk  |       proxy_read_timeout 60s;
# fae2hmw08w-algo-1-l8eyk  |       proxy_pass http://gunicorn;
# fae2hmw08w-algo-1-l8eyk  |     }
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |     location / {
# fae2hmw08w-algo-1-l8eyk  |       return 404 "{}";
# fae2hmw08w-algo-1-l8eyk  |     }
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |   }
# fae2hmw08w-algo-1-l8eyk  | }
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  |
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:13,155 INFO - sagemaker-containers - Module train does not provide a setup.py.
# fae2hmw08w-algo-1-l8eyk  | Generating setup.py
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:13,155 INFO - sagemaker-containers - Generating setup.cfg
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:13,156 INFO - sagemaker-containers - Generating MANIFEST.in
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:13,156 INFO - sagemaker-containers - Installing module with the following command:
# fae2hmw08w-algo-1-l8eyk  | /miniconda3/bin/python -m pip install .
# fae2hmw08w-algo-1-l8eyk  | Processing /opt/ml/code
# fae2hmw08w-algo-1-l8eyk  |   Preparing metadata (setup.py) ... done
# fae2hmw08w-algo-1-l8eyk  | Building wheels for collected packages: train
# fae2hmw08w-algo-1-l8eyk  |   Building wheel for train (setup.py) ... done
# fae2hmw08w-algo-1-l8eyk  |   Created wheel for train: filename=train-1.0.0-py2.py3-none-any.whl size=4299 sha256=868e92bde7982cf799bf0e447b3b45b6a056ca27939a467eab9bec2e868cddc3
# fae2hmw08w-algo-1-l8eyk  |   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-hw8ugteq/wheels/f3/75/57/158162e9eab7af12b5c338c279b3a81f103b89d74eeb911c00
# fae2hmw08w-algo-1-l8eyk  | Successfully built train
# fae2hmw08w-algo-1-l8eyk  | Installing collected packages: train
# fae2hmw08w-algo-1-l8eyk  | Successfully installed train-1.0.0
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [81] [INFO] Starting gunicorn 20.0.4
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [81] [INFO] Listening at: unix:/tmp/gunicorn.sock (81)
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [81] [INFO] Using worker: gevent
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [83] [INFO] Booting worker with pid: 83
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [84] [INFO] Booting worker with pid: 84
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [85] [INFO] Booting worker with pid: 85
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [86] [INFO] Booting worker with pid: 86
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [87] [INFO] Booting worker with pid: 87
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [88] [INFO] Booting worker with pid: 88
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [89] [INFO] Booting worker with pid: 89
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [90] [INFO] Booting worker with pid: 90
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:15 +0000] [91] [INFO] Booting worker with pid: 91
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [92] [INFO] Booting worker with pid: 92
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [93] [INFO] Booting worker with pid: 93
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [99] [INFO] Booting worker with pid: 99
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [114] [INFO] Booting worker with pid: 114
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [115] [INFO] Booting worker with pid: 115
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [116] [INFO] Booting worker with pid: 116
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [134] [INFO] Booting worker with pid: 134
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [137] [INFO] Booting worker with pid: 137
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [138] [INFO] Booting worker with pid: 138
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [139] [INFO] Booting worker with pid: 139
# fae2hmw08w-algo-1-l8eyk  | [2024-09-06 00:27:16 +0000] [159] [INFO] Booting worker with pid: 159
# INFO:sagemaker.local.entities:Checking if serving container is up, attempt: 10
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:27:19,715 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# fae2hmw08w-algo-1-l8eyk  | 172.18.0.1 - - [06/Sep/2024:00:27:22 +0000] "GET /ping HTTP/1.1" 200 0 "-" "python-urllib3/2.2.2"
# !

# %% [markdown]
# ## Test the local deployed endpoint

# %%
test_data = pd.read_csv("data/iris_test.csv")
test_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                6.1               2.8                4.7               1.2
# 1                5.7               3.8                1.7               0.3
# 2                7.7               2.6                6.9               2.3
# 3                6.0               2.9                4.5               1.5
# 4                6.8               2.8                4.8               1.4
#
#    label
# 0      1
# 1      0
# 2      2
# 3      1
# 4      1

# %%
test_df = test_data.drop('label', axis = 1)
pred_values = test_data['label']
test_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                6.1               2.8                4.7               1.2
# 1                5.7               3.8                1.7               0.3
# 2                7.7               2.6                6.9               2.3
# 3                6.0               2.9                4.5               1.5
# 4                6.8               2.8                4.8               1.4

# %%
print(predictor.predict(test_df.values))
print(pred_values.values)
# Out:
# fae2hmw08w-algo-1-l8eyk  | 2024-09-06 00:54:57,108 INFO - sagemaker-containers - No GPUs detected (normal if no gpus installed)
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 1 0 2 2 2 2 2 0 0]
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]
# fae2hmw08w-algo-1-l8eyk  | 172.18.0.1 - - [06/Sep/2024:00:54:57 +0000] "POST /invocations HTTP/1.1" 200 368 "-" "python-urllib3/2.2.2"
